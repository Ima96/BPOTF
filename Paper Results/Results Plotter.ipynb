# %%
# This jupyter notebook contains:
# - The data of the figures present in the paper
# - Plotter functions to obtain the figures of the paper

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# These lines are for saving the figures in pgf format
# matplotlib.use("pgf")
# matplotlib.rcParams.update({
#     "pgf.texsystem": "pdflatex",
#     'font.family': 'serif',
#     'text.usetex': True,
#     'pgf.rcfonts': False,
# })
import pandas as pd

# %%
# BB codes BP+OSD-0 vs BP+BP+OTF (Figure 2)

# We use the fit_binomial function from sinter to get the estimations, max_likelihood_factor=1000
# estimateOTF are the mean values
# upOTF are the higher error bar
# lowOTF are the lower error bar

fig, ax = plt.subplots(1, 1)
p = [4e-4,1e-3, 2e-3, 3e-3, 4e-3, 5e-3,6e-3,7e-3]
import matplotlib.patches as mpatches
# [[72,12,6]] code, OTF
estimateOTF72 = [9.704654999514767e-07,2.3583081308804414e-05,0.00030645705004443626,0.0018924340486734038,0.006241418050181001,0.017711654268508677,0.03324468085106383,0.057803468208092484]
upOTF72 = [1.4018913294299053e-06,2.9011906626091188e-05,0.0003769319563196552,0.0023250444722001436,0.007644904922398368,0.021517298382335574,0.03992242907801418,0.0680616570327553]
lowOTF72 = [6.382428104680878e-07,1.8877470484987638e-05,0.00024534951426557567,0.00151653356547191,0.0050149794033204345,0.014333451411028457,0.02717863475177305,0.04808670520231214]
# [[72,12,6]] code, OSD-0
estimateOSD72 = [9.294447712176588e-07,1.8918442660540033e-05,0.00027123861428607473,0.0013635152037071209,0.005545601911099735,0.012374860956618465,0.029456356941737056,0.05437769925402434]
upOSD72 = [1.3302800583417374e-06,2.3411405668366517e-05,0.00033886954473965296,0.0016966024891841465,0.006895102806927737,0.015265109380793474,0.035791639592809184,0.06462112288967413]
lowOSD72 = [6.18521036172425e-07,1.5040496163232868e-05,0.00021325873220128007,0.0010768694511082407,0.004379105878338026,0.009847515758249907,0.023763266190166776,0.044760502552021984]

plts = ax.plot(p, estimateOTF72,'b',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowOTF72,upOTF72,alpha=0.2,facecolor = plts[0].get_color())
plts = ax.plot(p, estimateOSD72,'b',marker='o',markersize=5)
ax.fill_between(p, lowOSD72,upOSD72,alpha=0.2,facecolor = plts[0].get_color())

p = [7e-4,1e-3, 2e-3, 3e-3, 4e-3, 5e-3,6e-3,7e-3]
# [[108,8,10]] code, OTF
estimateOTF108 = [1.3225090891382018e-06,3.1056243011374814e-06,4.980476531994581e-05,0.00034403669724770644,0.0014943960149439602,0.005970149253731343,0.018303843807199512,0.03496503496503496]
upOTF108 = [1.8707020723613701e-06,3.994919819768198e-06,6.126650197890935e-05,0.00042307339449541284,0.0018352677459526775,0.007293532338308458,0.02202684563758389,0.04115384615384616]
lowOTF108 = [8.936012394451457e-07,2.359342781574145e-06,3.9868714638616626e-05,0.0002754816513761468,0.0011980074719800747,0.004807960199004975,0.01493654667480171,0.029097902097902095]

# [[108,8,10]] code, OSD
estimateOSD108 = [1.6196905127761998e-06,4.365238730937797e-06,6.511513539850009e-05,0.0004990099009900991,0.002183363454305671,0.007581038689438829,0.021519659936238045,0.041742081447963805]
upOSD108 = [2.0834888911096646e-06,5.752987807491384e-06,7.750522514810278e-05,0.0005923394625176804,0.002584721340301861,0.008948065528058557,0.025174814027630183,0.047968325791855206]
lowOSD108 = [1.230478882556079e-06,3.220752503662832e-06,5.412145414695377e-05,0.000415988684582744,0.0018249890099154985,0.006350121993726037,0.018142933049946863,0.03568665158371041]

plts = ax.plot(p, estimateOTF108,'r',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowOTF108,upOTF108,alpha=0.2,facecolor = plts[0].get_color())
plts = ax.plot(p, estimateOSD108,'r',marker='o',markersize=5)
ax.fill_between(p, lowOSD108,upOSD108,alpha=0.2,facecolor = plts[0].get_color())

p = [1e-3, 2e-3, 3e-3, 4e-3, 5e-3,6e-3,7e-3]
# Gross code, OTF
estimateOTF144 = [2.475663640076658e-07,1.3048418505580288e-05,0.00012112227050963406,0.0009114440920193955,0.003962593120938342,0.011606313834726092,0.03654970760233918]
upOTF144 = [4.2822466069010196e-07,1.8517010701268985e-05,0.00017183616517201785,0.0012904225454810603,0.005567047075606277,0.015981894150417824,0.046779970760233915]
lowOTF144 = [1.2664973990286903e-07,8.780280812404975e-06,8.151528805298371e-05,0.0006144044624302746,0.0026874306546203833,0.007996750232126277,0.026725146198830412]
# Gross code, OSD
estimateOSD144 = [1.892191147888299e-07,9.87281648462816e-06,0.0001255188110858214,0.0010650224215246636,0.00510120796604636,0.018970189701897018,0.04013605442176871]
upOSD144 = [3.016993663577454e-07,1.3805713791107432e-05,0.0001700222028830276,0.0013942451420029896,0.006553215801501797,0.02210252935862692,0.04583673469387755]
lowOSD144 = [1.0890611273401542e-07,6.768965274734787e-06,8.9550698442451e-05,0.0007915732436472347,0.0038683480248122757,0.01606413730803975,0.03447278911564626]

plts = ax.plot(p, estimateOTF144,'g',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowOTF144,upOTF144,alpha=0.2,facecolor = plts[0].get_color())

plts = ax.plot(p, estimateOSD144,'g',marker='o',markersize=5)
ax.fill_between(p, lowOSD144,upOSD144,alpha=0.2,facecolor = plts[0].get_color())

# [[288,12,18]] code, OTF
estimateOTF288 = [1.3432285217490727e-06,2.3050280498863392e-05,0.00028100938571348283,0.0025803787996077823,0.013196093956188967,0.035385704175513094]
upOTF288 = [1.906175595214109e-06,3.2708348027887155e-05,0.0003983589051874332,0.003625948289208856,0.017765901293217208,0.0427105449398443]
lowOTF288 = [9.038584722849511e-07,1.5510533747685178e-05,0.00018923172033945935,0.0017497548640140375,0.009258379519662178,0.027190375088464263]
# [[288,12,18]] code, OSD
estimateOSD288 = [1.1112412076427375e-05,0.00015533887773635407,0.0016384907509494058,0.009839443023586246,0.033421868083222665]
upOSD288 = [1.631762851369049e-05,0.00023004094573495203,0.0022860774225162317,0.011935208866155157,0.03780101814962373]
lowOSD288 = [7.152598895046792e-06,9.883933976993915e-05,0.0011233615092490505,0.007954319408922989,0.028836874723328902]

p=[2e-3,3e-3,4e-3,5e-3,6e-3,7e-3]
plts = ax.plot(p, estimateOTF288,'m',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowOTF288,upOTF288,alpha=0.2,facecolor = plts[0].get_color())
p=[3e-3,4e-3,5e-3,6e-3,7e-3]
plts = ax.plot(p, estimateOSD288,'m',marker='o',markersize=5)
ax.fill_between(p, lowOSD288,upOSD288,alpha=0.2,facecolor = plts[0].get_color())
ax.set_ylim(1e-7, 1e-1)
ax.set_xlim(3e-4, 8e-3)
ax.grid(which='major')
ax.grid(which='minor')
ax.loglog()
ax.set_xlabel("physical error rate",fontname='Arial')
ax.set_ylabel("logical error rate per round",fontname='Arial' )
#label
label_column = ['BP+BP+OTF','BP+OSD-0']
label_row = ['$[[72,12,6]]$', '$[[108,8,10]]$', '$[[144,12,12]]$', '$[[288,12,18]]$']
rows = [mpatches.Patch(color='b'),mpatches.Patch(color='r'),mpatches.Patch(color='g'),mpatches.Patch(color='m')]
columns = [plt.plot([], [],'k', linestyle='--')[0],plt.plot([], [],'k', linestyle='-')[0]]


ax.legend(rows + columns, label_row + label_column, loc=2, prop={'size': 12})
ax.set_xlabel("physical error rate",fontname='Arial')
ax.set_ylabel("logical error rate per round",fontname='Arial' )
ax.grid()
plt.rcParams.update({'font.size': 15})

# Uncomment this to save the pgf image
# plt.savefig("BBcodesPerformance.pgf")

# %%
# Figure 7(b)
# BP+OSD vs BP+BP+OSD (1000 iters on DEM,9000 in sparse)
import matplotlib.patches as mpatches

# We use the fit_binomial function from sinter to get the estimations, max_likelihood_factor=1000
# estimateBPBPOSD are the mean values
# upBPBPOSD are the higher error bar
# lowBPBPOSD are the lower error bar

fig, ax = plt.subplots(1, 1)
p = [1e-3,2e-3, 3e-3, 4e-3, 5e-3,6e-3,7e-3]


# [[72,12,6]] code, BPBPOSD-0
estimateBPBPOSD72 = [1.8598376290217648e-05,0.0003446401823941888,0.0016484765802637564,0.0056362958822433395,0.016634050880626222,0.028225806451612902,0.06027253668763102]
upBPBPOSD72 = [2.622371056920688e-05,0.0004857438263013481,0.0022802978626648477,0.007711477547978387,0.023036529680365295,0.03833602150537635,0.0774475890985325]
lowBPBPOSD72 = [1.2616494685335144e-05,0.0002338913853209793,0.0011448385629831742,0.003960313024035774,0.011428571428571429,0.019741935483870966,0.044412997903563935]
# [[72,12,6]] code, BPOSD-0
estimateOSD72 = [1.7883054125209277e-05,0.0003313847907636431,0.001421100500227376,0.004658095770449041,0.016307893020221786,0.026881720430107527,0.05241090146750524]
upOSD72 = [2.5377842109084485e-05,0.00047006932569822776,0.0020131309686221006,0.006571641512949506,0.02266307893020222,0.036833333333333336,0.06926100628930817]
lowOSD72 = [1.2033507120853324e-05,0.0002230551026630082,0.000957537517053206,0.003148872740823551,0.011154598825831703,0.018594086021505377,0.037327044025157234]

plts = ax.plot(p, estimateBPBPOSD72,'b',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowBPBPOSD72,upBPBPOSD72,alpha=0.2,facecolor = plts[0].get_color())
plts = ax.plot(p, estimateOSD72,'b',marker='o',markersize=5)
ax.fill_between(p, lowOSD72,upOSD72,alpha=0.2,facecolor = plts[0].get_color())


p = [1e-3, 2e-3, 3e-3, 4e-3, 5e-3, 6e-3, 7e-3]


# [[108,8,10]] code, BPBPOSD-0
estimateBPBPOSD108 = [5.518692414815965e-06,7.144572174819482e-05,0.0006128995303012945,0.0029635072250795984,0.009015715467328371,0.02012072434607646,0.04201680672268908]
upBPBPOSD108 = [7.535602033293236e-06,9.824372361046856e-05,0.0008592049490205063,0.004057800636786677,0.012387096774193546,0.02731790744466801,0.054042016806722694]
lowBPBPOSD108 = [3.89843881365359e-06,5.002371763713772e-05,0.0004186046511627907,0.0020808229243203524,0.006265508684863523,0.014020120724346077,0.030596638655462183]

# [[108,8,100]] code, BPOSD-0
estimateOSD108 = [4.311478449074973e-06,5.856206700671707e-05,0.0005728032993470042,0.002449179524859172,0.008271298593879239,0.022334004024144868,0.04201680672268908]
upOSD108 = [6.118419067082294e-06,8.309371687583085e-05,0.0008118913964944439,0.0034577516531961797,0.011532671629445823,0.029748490945674045,0.054042016806722694]
lowOSD108 = [2.901193848382549e-06,3.940641488881992e-05,0.00038578302211020733,0.0016546656869948569,0.005642679900744417,0.015937625754527163,0.030596638655462183]

plts = ax.plot(p, estimateBPBPOSD108,'r',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowBPBPOSD108,upBPBPOSD108,alpha=0.2,facecolor = plts[0].get_color())
plts = ax.plot(p, estimateOSD108,'r',marker='o',markersize=5)
ax.fill_between(p, lowOSD108,upOSD108,alpha=0.2,facecolor = plts[0].get_color())


# Gross code, BPBPOSD-0
estimateBPBPOSD144 = [1.2705499867751513e-05,0.00019029916799433527,0.0010855683269476372,0.006520605112154409,0.020037453183520598,0.03791291291291291]
upBPBPOSD144 = [1.7177464857700258e-05,0.0002594411990322771,0.0015313963388676032,0.009100156494522692,0.026715355805243448,0.04825825825825825]
lowBPBPOSD144 = [9.086750927316008e-06,0.00013466985307134007,0.0007349936143039591,0.0044450965049556606,0.014245318352059923,0.027871621621621625]
# Gross code, BPOSD-0
estimateOSD144 = [9.274087494709133e-06,0.0001475187348793297,0.0010642826734780758,0.006520605112154409,0.018726591760299626,0.03753753753753754]
upOSD144 = [1.316085756374173e-05,0.00020927007729981708,0.0015062792677735207,0.009100156494522692,0.025286516853932586,0.04789039039039039]
lowOSD144 = [6.240533475189776e-06,9.92948604472768e-05,0.0007176458067262667,0.0044450965049556606,0.013106741573033707,0.02752252252252252]


p = [2e-3, 3e-3, 4e-3, 5e-3, 6e-3, 7e-3]
plts = ax.plot(p, estimateBPBPOSD144,'g',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowBPBPOSD144,upBPBPOSD144,alpha=0.2,facecolor = plts[0].get_color())

plts = ax.plot(p, estimateOSD144,'g',marker='o',markersize=5)
ax.fill_between(p, lowOSD144,upOSD144,alpha=0.2,facecolor = plts[0].get_color())


# [[288,12,18]] code, BPBPOSD-0
estimateBPBPOSD288 = [1.2204164939777328e-05,0.0001663861319093776,0.0018081259306530527,0.00949667616334283,0.03301587301587302]
upBPBPOSD288 = [1.978783303335496e-05,0.0002420918219281444,0.002540239665319436,0.012983855650522317,0.040263492063492064]
lowBPBPOSD288 = [6.861181529142814e-06,0.0001083444579875017,0.0012282847621073532,0.006580246913580248,0.025228571428571427]
# [[288,12,18]] code, BPOSD-0
estimateOSD288 = [1.2448248238572874e-05,0.00012962640509218954,0.0017726724810324043,0.01063627730294397,0.031746031746031744]
upOSD288 = [2.0095377989837347e-05,0.0001975932052547062,0.0024987591292632777,0.01424881291547958,0.039117460317460315]
lowOSD288 = [7.041803170251518e-06,7.934296825120435e-05,0.0011990356661703185,0.007559354226020891,0.023965079365079363]


p=[3e-3,4e-3,5e-3,6e-3,7e-3]
plts = ax.plot(p, estimateBPBPOSD288,'m',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowBPBPOSD288,upBPBPOSD288,alpha=0.2,facecolor = plts[0].get_color())
plts = ax.plot(p, estimateOSD288,'m',marker='o',markersize=5)
ax.fill_between(p, lowOSD288,upOSD288,alpha=0.2,facecolor = plts[0].get_color())
ax.set_ylim(1e-6, 1e-1)
ax.set_xlim(3e-4, 8e-3)
ax.grid(which='major')
ax.grid(which='minor')
ax.loglog()
ax.set_xlabel("physical error rate",fontname='Arial')
ax.set_ylabel("logical error rate per round",fontname='Arial' )
#label
label_column = ['BP+BP+OSD-0','BP+OSD-0']
label_row = ['$[[72,12,6]]$', '$[[108,8,10]]$', '$[[144,12,12]]$', '$[[288,12,18]]$']
rows = [mpatches.Patch(color='b'),mpatches.Patch(color='r'),mpatches.Patch(color='g'),mpatches.Patch(color='m')]
columns = [plt.plot([], [],'k', linestyle='--')[0],plt.plot([], [],'k', linestyle='-')[0],plt.plot([], [],'k', linestyle='-')[0]]

ax.legend(rows + columns, label_row + label_column, loc=2,prop={'size': 12})

ax.grid()
# plt.savefig("BBcodesPerformanceBPBPOSD.pgf")
# plt.savefig("BBcodesPerformanceBPBPOSD.pdf", format="pdf", bbox_inches="tight")

# %%
# Figure 7(a)
# # BP+OSD (all in the full DEM) vs BP+OSDsparse (all in the sparse model)
import matplotlib.patches as mpatches

# We use the fit_binomial function from sinter to get the estimations, max_likelihood_factor=1000
# estimateSp are the mean values
# upSp are the higher error bar
# lowSp are the lower error bar

fig, ax = plt.subplots(1, 1)
p = [1e-3,2e-3, 3e-3, 4e-3, 5e-3,6e-3,7e-3]


# [[72,12,6]] code, all sparse
estimateSp72 =[0.0007037693888466627,0.003972036860502065,0.013175230566534914,0.030248033877797943,0.04873294346978557,0.06561679790026247,0.08960573476702509]
upSp72 = [0.0009978042395067984,0.005608516047028916,0.018384716732542817,0.04125529340592861,0.0647514619883041,0.08498687664041994,0.11153225806451612]
lowSp72 = [0.00047384792951045803,0.0026831108992691455,0.008982872200263505,0.021001209921355114,0.034556530214424945,0.04750656167979003,0.06706989247311827]

# [[72,12,6]] code, OSD full DEM
estimateOSD72 = [1.7883054125209277e-05,0.0003313847907636431,0.001421100500227376,0.004658095770449041,0.016307893020221786,0.026881720430107527,0.05241090146750524]
upOSD72 = [2.5377842109084485e-05,0.00047006932569822776,0.0020131309686221006,0.006571641512949506,0.02266307893020222,0.036833333333333336,0.06926100628930817]
lowOSD72 = [1.2033507120853324e-05,0.0002230551026630082,0.000957537517053206,0.003148872740823551,0.011154598825831703,0.018594086021505377,0.037327044025157234]
plts = ax.plot(p, estimateSp72,'b',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowSp72,upSp72,alpha=0.2,facecolor = plts[0].get_color())
plts = ax.plot(p, estimateOSD72,'b',marker='o',markersize=5)
ax.fill_between(p, lowOSD72,upOSD72,alpha=0.2,facecolor = plts[0].get_color())


p = [1e-3, 2e-3, 3e-3, 4e-3, 5e-3, 6e-3, 7e-3]

# [[108,8,10]] code, all sparse
estimateSp108 =[0.00014283877787141653,0.0012274456855284155,0.005509641873278237,0.014947683109118088,0.03717472118959107,0.05494505494505495,0.06711409395973154]
upSp108 = [0.00020264537416617864,0.001737326623296919,0.007727823691460055,0.020535127055306426,0.048423791821561334,0.06815384615384615,0.08008724832214766]
lowSp108 = [9.613049750746332e-05,0.0008275438811832577,0.003741046831955923,0.010318385650224216,0.026788104089219333,0.041247252747252744,0.05208724832214765]


# [[108,8,10]] code, OSD full DEM
estimateOSD108 = [4.311478449074973e-06,5.856206700671707e-05,0.0005728032993470042,0.002449179524859172,0.008271298593879239,0.022334004024144868,0.04201680672268908]
upOSD108 = [6.118419067082294e-06,8.309371687583085e-05,0.0008118913964944439,0.0034577516531961797,0.011532671629445823,0.029748490945674045,0.054042016806722694]
lowOSD108 = [2.901193848382549e-06,3.940641488881992e-05,0.00038578302211020733,0.0016546656869948569,0.005642679900744417,0.015937625754527163,0.030596638655462183]
plts = ax.plot(p, estimateSp108,'r',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowSp108,upSp108,alpha=0.2,facecolor = plts[0].get_color())
plts = ax.plot(p, estimateOSD108,'r',marker='o',markersize=5)
ax.fill_between(p, lowOSD108,upOSD108,alpha=0.2,facecolor = plts[0].get_color())

p = [1e-3,2e-3, 3e-3, 4e-3, 5e-3, 6e-3, 7e-3]

# Gross code, all sparse
estimateSp144 =[2.024063688378393e-05,0.00041121802779833864,0.004010266281681103,0.014854426619132501,0.029342723004694832,0.05518763796909493,0.07062146892655367]
upSp144 = [2.87214637380894e-05,0.0005829426762069249,0.005633221045877446,0.020274806892453954,0.038415492957746475,0.06605408388520971,0.07853107344632769]
lowSp144 = [1.3619924559098207e-05,0.0002769142199194013,0.0027201636188642925,0.010307486631016043,0.021059272300469483,0.042715231788079476,0.05836864406779662]

# Gross code, OSD full DEM
estimateOSD144 = [9.274087494709133e-06,0.0001475187348793297,0.0010642826734780758,0.006520605112154409,0.018726591760299626,0.03753753753753754]
upOSD144 = [1.316085756374173e-05,0.00020927007729981708,0.0015062792677735207,0.009100156494522692,0.025286516853932586,0.04789039039039039]
lowOSD144 = [6.240533475189776e-06,9.92948604472768e-05,0.0007176458067262667,0.0044450965049556606,0.013106741573033707,0.02752252252252252]

plts = ax.plot(p, estimateSp144,'g',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowSp144,upSp144,alpha=0.2,facecolor = plts[0].get_color())
p = [2e-3, 3e-3, 4e-3, 5e-3, 6e-3, 7e-3]

plts = ax.plot(p, estimateOSD144,'g',marker='o',markersize=5)
ax.fill_between(p, lowOSD144,upOSD144,alpha=0.2,facecolor = plts[0].get_color())

p=[2e-3,3e-3,4e-3,5e-3,6e-3,7e-3]
# [[288,12,18]] code, all sparse
estimateSp288 =[1.5719151165837046e-05,0.0005451968160505942,0.004244121891180714,0.02286236854138089,0.044444444444444446,0.05393743257820928]
upSp288 = [2.506040229383169e-05,0.0007721077308908516,0.005925642984466514,0.02947416552354824,0.05049777777777778,0.0554908306364617]
lowSp288 = [9.0501557360347e-06,0.0003674081343364955,0.002892369068839657,0.01661636945587563,0.03602222222222222,0.04807982740021575]
# [[288,12,18]] code, OSD full DEM
estimateOSD288 = [1.2448248238572874e-05,0.00012962640509218954,0.0017726724810324043,0.01063627730294397,0.031746031746031744]
upOSD288 = [2.0095377989837347e-05,0.0001975932052547062,0.0024987591292632777,0.01424881291547958,0.039117460317460315]
lowOSD288 = [7.041803170251518e-06,7.934296825120435e-05,0.0011990356661703185,0.007559354226020891,0.023965079365079363]

plts = ax.plot(p, estimateSp288,'m',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowSp288,upSp288,alpha=0.2,facecolor = plts[0].get_color())
p=[3e-3,4e-3,5e-3,6e-3,7e-3]
plts = ax.plot(p, estimateOSD288,'m',marker='o',markersize=5)
ax.fill_between(p, lowOSD288,upOSD288,alpha=0.2,facecolor = plts[0].get_color())
ax.set_ylim(1e-6, 1e-1)
ax.set_xlim(3e-4, 8e-3)
ax.grid(which='major')
ax.grid(which='minor')
ax.loglog()
ax.set_xlabel("physical error rate",fontname='Arial')
ax.set_ylabel("logical error rate per round",fontname='Arial' )
#label
label_column = ['BP+OSD-0 SDEM','BP+OSD-0 DEM']
label_row = ['$[[72,12,6]]$', '$[[108,8,10]]$', '$[[144,12,12]]$', '$[[288,12,18]]$']
rows = [mpatches.Patch(color='b'),mpatches.Patch(color='r'),mpatches.Patch(color='g'),mpatches.Patch(color='m')]
columns = [plt.plot([], [],'k', linestyle='--')[0],plt.plot([], [],'k', linestyle='-')[0],plt.plot([], [],'k', linestyle='-')[0]]

ax.legend(rows + columns, label_row + label_column, loc=2,prop={'size': 12})

ax.grid()
# plt.savefig("BBcodesPerformanceBPOSDsparse.pgf")
# plt.savefig("BBcodesPerformanceBPOSDsparse.pdf", format="pdf", bbox_inches="tight")

# %%
# Figure 4(a)
# MWPM vs BP+BP+OTF 
import matplotlib.patches as mpatches

# We use the fit_binomial function from sinter to get the estimations, max_likelihood_factor=1000
# estimateOTF are the mean values
# upOTF are the higher error bar
# lowOTF are the lower error bar



fig, ax = plt.subplots(1, 1)
p = [1e-3,2e-3,3e-3,4e-3,5e-3,6e-3,7e-3,8e-3,9e-3,1e-2]
# d=5 code, OTF
estimateOTF5 = [2.476109788765987e-05,0.0001831149687331191,0.0005403360890473875,0.0012560184216035169,0.0024260067928190197,0.003826530612244898,0.0061312078479460455,0.00796918581484925,0.011441647597254006,0.015523932729624837]
upOTF5 = [3.0401125739849064e-05,0.0002252497230386098,0.0006645233335134454,0.0015440653129579235,0.002980349344978166,0.004697066326530612,0.0075158389536071945,0.009758533669810068,0.013982074752097636,0.018924708926261323]
lowOTF5 = [1.9865521344511433e-05,0.00014658963630315294,0.0004326471065002432,0.001006028888423697,0.0019442827106582565,0.0030688775510204084,0.004922951154710811,0.006404834639394343,0.00921205186880244,0.01252522639068564]
# d=5 code, MWPM
estimateMWPM5 = [2.4275586164372422e-05,0.00019288110039888544,0.0006520055474505142,0.0014402344567720326,0.0027252142972666988,0.00461734693877551,0.006846515430206418,0.008766104396334174,0.012242562929061784,0.017335058214747737]
upMWPM5 = [2.9863826099410953e-05,0.00023604740236157274,0.0007875398497865673,0.001747121624450492,0.0033099628012291772,0.005565561224489796,0.008301451052524014,0.010632487714171869,0.01485812356979405,0.020895730918499354]
lowMWPM5 = [1.9431797538374644e-05,0.0001553242203117227,0.0005329514958304065,0.0011713627799874397,0.002212922529516416,0.003781122448979592,0.005566727978745146,0.007122858281312259,0.009934782608695653,0.01416765847347995]
plts = ax.plot(p, estimateOTF5,'b',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowOTF5,upOTF5,alpha=0.2,facecolor = plts[0].get_color())
plts = ax.plot(p, estimateMWPM5,'b',marker='o',markersize=5)
ax.fill_between(p, lowMWPM5,upMWPM5,alpha=0.2,facecolor = plts[0].get_color())

p = [1e-3,2e-3,3e-3,4e-3,5e-3,6e-3,7e-3,8e-3,9e-3,1e-2]
# d=9 code, OTF
estimateOTF9 = [2.761118084558462e-07,6.8595250722072194e-06,5.163131728528729e-05,0.00020781509444156967,0.0006618352692014958,0.0016272068993572533,0.002987393200693075,0.0060299083453931495,0.008689607229753215,0.012708095056551023]
upOTF9 = [6.048472792291596e-07,9.208912409438192e-06,6.351340443654141e-05,0.00025559871182350124,0.0008136382187806789,0.0019984270333306214,0.0036637390213299877,0.00737136195529828,0.010592341559494844,0.015423391366967425]
lowOTF9 = [9.566462069440788e-08,4.948385170145041e-06,4.133086948687248e-05,0.0001663836917797354,0.000530085928279118,0.0013044232907547528,0.0023977813626496185,0.0048532722302621,0.007011354420113545,0.010293133392637778]
# d=9 code, MWPM
estimateMWPM9= [2.761118084558462e-07,7.859872478570772e-06,6.29902070880505e-05,0.00024245094351516464,0.0007236065609936353,0.0017465354053101184,0.0033558383621118877,0.006271104679208876,0.009935117599351177,0.013131698225102724]
upMWPM9 = [6.048472792291596e-07,1.0358359214940692e-05,7.602883574649505e-05,0.00029379512618186174,0.0008818072515084328,0.002129959591028666,0.004068530800023899,0.007635471940826499,0.011947051326613368,0.015882153598508916]
lowMWPM9 = [9.566462069440788e-08,5.799633177369646e-06,5.1534938826354756e-05,0.0001974589755685648,0.0005854374179600032,0.0014114392645024818,0.0027292824281531934,0.005070750924585946,0.008141872320704437,0.010678612276019826]
plts = ax.plot(p, estimateOTF9,'r',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowOTF9,upOTF9,alpha=0.2,facecolor = plts[0].get_color())
plts = ax.plot(p, estimateMWPM9,'r',marker='o',markersize=5)
ax.fill_between(p, lowMWPM9,upMWPM9,alpha=0.2,facecolor = plts[0].get_color())
p = [2e-3,3e-3,4e-3,5e-3,6e-3,7e-3,8e-3,9e-3,1e-2]

# d=13 code, OTF
estimateOTF13 = [3.829324602745547e-07,5.639025666589224e-06,4.4213746938198025e-05,0.00024141061047915178,0.000638630775617077,0.0016528379227132987,0.0037214841278701946,0.007382253063635021,0.011619800139437602]
upOTF13 = [7.045957269051807e-07,8.22767015494583e-06,6.273488553060917e-05,0.000342368527781533,0.0009046843567391512,0.0023349641334170774,0.005227196606006476,0.010262808209065407,0.015958633511503603]
lowOTF13 = [1.7819123818109276e-07,3.660059365008559e-06,2.975143031471345e-05,0.00016251762297456496,0.0004303094166107864,0.0011159961654160192,0.0025242826839343533,0.005047984644913627,0.008023471996281664]
# d=13 code, MWPM
estimateMWPM13 = [3.063459682196437e-07,5.9043915803110704e-06,5.4382908733983565e-05,0.0002462388226887348,0.0007663569307404924,0.0019503487488016923,0.0038703434929850027,0.007972833308725823,0.01347896816174762]
upMWPM13 = [6.00948674324201e-07,8.54544583662774e-06,7.469028270269793e-05,0.00034806581818884106,0.0010545709997764792,0.002682721232355955,0.005400617766365226,0.01093828436438801,0.018033929816407158]
lowMWPM13 = [1.285376624988255e-07,3.87301551077034e-06,3.813877810888962e-05,0.00016645261592537517,0.0005356834945876041,0.0013621037321080293,0.0026470916601540693,0.005543333825483538,0.009614222635370671]
plts = ax.plot(p, estimateOTF13,'g',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowOTF13,upOTF13,alpha=0.2,facecolor = plts[0].get_color())
plts = ax.plot(p, estimateMWPM13,'g',marker='o',markersize=5)
ax.fill_between(p, lowMWPM13,upMWPM13,alpha=0.2,facecolor = plts[0].get_color())

# d=17 code, OTF
estimateOTF17 = [1.220012846735276e-06,1.220706552276697e-05,0.000107832187408057,0.00044298162069255747,0.0015677912956227266,0.003890445066915655,0.007609770945894529,0.012815583749839807]
upOTF17 = [2.2448236379929083e-06,1.7321825976806332e-05,0.0001437738694759213,0.0006276606583592847,0.002212467076382792,0.005443899782135077,0.010501483905334449,0.017333077021658337]
lowOTF17 = [5.677126446808151e-07,8.214134390269895e-06,7.843898983378133e-05,0.000298436717860576,0.0010595133575818387,0.0026466697790227204,0.005234000456586257,0.008958093041138024]
# d=17 code, MWPM
estimateMWPM17 = [7.320077080411656e-07,6.591815382294165e-06,7.141204464109735e-05,0.00030565731827786465,0.0010817759939796814,0.003190164954870837,0.006392207594551404,0.013968986287325388]
upMWPM17 = [1.572596559441771e-06,1.051028341510236e-05,0.0001013122677323248,0.0004629157936237225,0.0016326978552615077,0.004624572051042639,0.00910889582223575,0.018591567345892603]
lowMWPM17 = [2.627094329969961e-07,3.7939559644759744e-06,4.806030604345851e-05,0.00018866587225296023,0.0006694468832309044,0.002073607220666044,0.004220378966593105,0.009960271690375496]
p = [3e-3,4e-3,5e-3,6e-3,7e-3,8e-3,9e-3,1e-2]
plts = ax.plot(p, estimateOTF17,'m',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowOTF17,upOTF17,alpha=0.2,facecolor = plts[0].get_color())

plts = ax.plot(p, estimateMWPM17,'m',marker='o',markersize=5)
ax.fill_between(p, lowMWPM17,upMWPM17,alpha=0.2,facecolor = plts[0].get_color())
ax.set_ylim(1e-7, 1e-1)
ax.set_xlim(1e-3, 1.1e-2)
ax.grid(which='major')
ax.grid(which='minor')
ax.loglog()
#label
label_column = ['BP+BP+OTF','MWPM']
label_row = ['$d=5$', '$d=9$', '$d=13$', '$d=17$']
rows = [mpatches.Patch(color='b'),mpatches.Patch(color='r'),mpatches.Patch(color='g'),mpatches.Patch(color='m')]
columns = [plt.plot([], [],'k', linestyle='--')[0],plt.plot([], [],'k', linestyle='-')[0]]
ax.legend(rows + columns, label_row + label_column, loc=4, prop={'size': 12})
ax.set_xlabel("physical error rate",fontname='Arial')
ax.set_ylabel("logical error rate per round",fontname='Arial' )
ax.grid()
plt.rcParams.update({'font.size': 15})
# plt.savefig("SCMWPMvsOTF.pdf", format = "pdf", bbox_inches = "tight")
# plt.savefig("SCMWPMvsOTF.pgf")

# %%
# Figure 4(b)
# BPOSD-0 vs BP+BP+OTF 
import matplotlib.patches as mpatches

# We use the fit_binomial function from sinter to get the estimations, max_likelihood_factor=1000
# estimateOTF are the mean values
# upOTF are the higher error bar
# lowOTF are the lower error bar

fig, ax = plt.subplots(1, 1)
p = [1e-3,2e-3,3e-3,4e-3,5e-3,6e-3,7e-3,8e-3,9e-3,1e-2]

# d=5 code, OTF
estimateOTF5 = [2.476109788765987e-05,0.0001831149687331191,0.0005403360890473875,0.0012560184216035169,0.0024260067928190197,0.003826530612244898,0.0061312078479460455,0.00796918581484925,0.011441647597254006,0.015523932729624837]
upOTF5 = [3.0401125739849064e-05,0.0002252497230386098,0.0006645233335134454,0.0015440653129579235,0.002980349344978166,0.004697066326530612,0.0075158389536071945,0.009758533669810068,0.013982074752097636,0.018924708926261323]
lowOTF5 = [1.9865521344511433e-05,0.00014658963630315294,0.0004326471065002432,0.001006028888423697,0.0019442827106582565,0.0030688775510204084,0.004922951154710811,0.006404834639394343,0.00921205186880244,0.01252522639068564]
# d=5 code, OSD
estimateOSD5 = [0.00013224366816184133,0.0007725203476341564,0.001749658647397866,0.0033845555339428123,0.0059576385759351055,0.00866129532073133,0.011010421386497509,0.015230664857530529,0.020429009193054137,0.02560819462227913]
upOSD5 = [0.00015630238774862944,0.0009325848658170358,0.002001353327130584,0.003879206380081696,0.006845335736818387,0.010058723272389217,0.012908246488445855,0.01793113975576662,0.023795709908069458,0.03026888604353393]
lowOSD5 = [0.00011079017715554346,0.0006318537304880249,0.0015198347007576215,0.002933184205407508,0.00514799459215863,0.007394174155562443,0.00929814227458088,0.012794776119402985,0.017361389172625127,0.021385403329065304]
plts = ax.plot(p, estimateOTF5,'b',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowOTF5,upOTF5,alpha=0.2,facecolor = plts[0].get_color())
plts = ax.plot(p, estimateOSD5,'b',marker='o',markersize=5)
ax.fill_between(p, lowOSD5,upOSD5,alpha=0.2,facecolor = plts[0].get_color())

p = [1e-3,2e-3,3e-3,4e-3,5e-3,6e-3,7e-3,8e-3,9e-3,1e-2]
# d=9 code, OTF
estimateOTF9 = [2.761118084558462e-07,6.8595250722072194e-06,5.163131728528729e-05,0.00020781509444156967,0.0006618352692014958,0.0016272068993572533,0.002987393200693075,0.0060299083453931495,0.008689607229753215,0.012708095056551023]
upOTF9 = [6.048472792291596e-07,9.208912409438192e-06,6.351340443654141e-05,0.00025559871182350124,0.0008136382187806789,0.0019984270333306214,0.0036637390213299877,0.00737136195529828,0.010592341559494844,0.015423391366967425]
lowOTF9 = [9.566462069440788e-08,4.948385170145041e-06,4.133086948687248e-05,0.0001663836917797354,0.000530085928279118,0.0013044232907547528,0.0023977813626496185,0.0048532722302621,0.007011354420113545,0.010293133392637778]
# d=9 code, OSD
estimateOSD9 = [1.1032359919533497e-06,2.3438374653442437e-05,0.00014254916261438274,0.0005550957374446872,0.0014510823744552503,0.003315894953280758,0.006535312290707974,0.010975135975135976,0.01580233169434394,0.021380471380471378]
upOSD9 = [1.7890074845515516e-06,3.3606639742457146e-05,0.00016178552415845455,0.0006384263781494434,0.001678624440407063,0.0038195778350381304,0.007537429515846782,0.012675990675990675,0.018309366979002383,0.024664983164983164]
lowOSD9 = [6.202392746761732e-07,1.5564078147530607e-05,0.00012489898447976555,0.000479321026777984,0.0012448434327241636,0.0028572395304651103,0.005620908678462636,0.009417832167832168,0.013498778489037326,0.01833375420875421]
plts = ax.plot(p, estimateOTF9,'r',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowOTF9,upOTF9,alpha=0.2,facecolor = plts[0].get_color())
plts = ax.plot(p, estimateOSD9,'r',marker='o',markersize=5)
ax.fill_between(p, lowOSD9,upOSD9,alpha=0.2,facecolor = plts[0].get_color())

p = [2e-3,3e-3,4e-3,5e-3,6e-3,7e-3,8e-3,9e-3,1e-2]
# d=13 code, OTF
estimateOTF13 = [3.829324602745547e-07,5.639025666589224e-06,4.4213746938198025e-05,0.00024141061047915178,0.000638630775617077,0.0016528379227132987,0.0037214841278701946,0.007382253063635021,0.011619800139437602]
upOTF13 = [7.045957269051807e-07,8.22767015494583e-06,6.273488553060917e-05,0.000342368527781533,0.0009046843567391512,0.0023349641334170774,0.005227196606006476,0.010262808209065407,0.015958633511503603]
lowOTF13 = [1.7819123818109276e-07,3.660059365008559e-06,2.975143031471345e-05,0.00016251762297456496,0.0004303094166107864,0.0011159961654160192,0.0025242826839343533,0.005047984644913627,0.008023471996281664]
# d=13 code, OSD
estimateOSD13 = [1.211713880424843e-06,2.060668476061382e-05,0.0001332969965830493,0.000586623795352521,0.0017342906694019127,0.004379452670580703,0.008704954789923355,0.015092342966565043,0.02247191011235955]
upOSD13 = [2.082594394996852e-06,3.0001895335772745e-05,0.0001514659209504323,0.0006670887796747414,0.002005634301812291,0.005030717467409517,0.010007034306900949,0.01721585325908942,0.025805723614712377]
lowOSD13 = [6.260521715528355e-07,1.3413514103478623e-05,0.00011664063887652216,0.0005128525283928872,0.0014880613944611271,0.0037836972660772908,0.0075072174919764935,0.013109425785482123,0.019321521175453757]
plts = ax.plot(p, estimateOTF13,'g',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowOTF13,upOTF13,alpha=0.2,facecolor = plts[0].get_color())
plts = ax.plot(p, estimateOSD13,'g',marker='o',markersize=5)
ax.fill_between(p, lowOSD13,upOSD13,alpha=0.2,facecolor = plts[0].get_color())

# d=17 code, OTF
estimateOTF17 = [1.220012846735276e-06,1.220706552276697e-05,0.000107832187408057,0.00044298162069255747,0.0015677912956227266,0.003890445066915655,0.007609770945894529,0.012815583749839807]
upOTF17 = [2.2448236379929083e-06,1.7321825976806332e-05,0.0001437738694759213,0.0006276606583592847,0.002212467076382792,0.005443899782135077,0.010501483905334449,0.017333077021658337]
lowOTF17 = [5.677126446808151e-07,8.214134390269895e-06,7.843898983378133e-05,0.000298436717860576,0.0010595133575818387,0.0026466697790227204,0.005234000456586257,0.008958093041138024]
# d=17 code, OSD
estimateOSD17 = [4.89001991331925e-06,5.031529009242385e-05,0.00032865399238491403,0.0012554735585020057,0.003690276640808742,0.007631160572337044,0.014584917398216631,0.021160500399254725]
upOSD17 = [6.5159515344979e-06,5.889461881784225e-05,0.0003877425207000122,0.0015274673117555196,0.0045307241518211,0.009445786963434023,0.017969862445565775,0.02628426936385414]
lowOSD17 = [3.5600631816309745e-06,4.2611714238121686e-05,0.0002758687016921875,0.0010172015188167926,0.0029543003417404077,0.00603275039745628,0.011519319831340292,0.01637742879957413]
p = [3e-3,4e-3,5e-3,6e-3,7e-3,8e-3,9e-3,1e-2]
plts = ax.plot(p, estimateOTF17,'m',linestyle='--',marker='o',markersize=5)
ax.fill_between(p, lowOTF17,upOTF17,alpha=0.2,facecolor = plts[0].get_color())
# p=[3e-3,4e-3,5e-3,6e-3,7e-3]
plts = ax.plot(p, estimateOSD17,'m',marker='o',markersize=5)
ax.fill_between(p, lowOSD17,upOSD17,alpha=0.2,facecolor = plts[0].get_color())
ax.set_ylim(1e-7, 1e-1)
ax.set_xlim(1e-3, 1.1e-2)
ax.grid(which='major')
ax.grid(which='minor')
ax.loglog()
ax.set_xlabel("physical error rate",fontname='Arial')
ax.set_ylabel("logical error rate per round",fontname='Arial' )
#label
label_column = ['BP+BP+OTF','BP+OSD']
label_row = ['$d=5$', '$d=9$', '$d=13$', '$d=17$']
rows = [mpatches.Patch(color='b'),mpatches.Patch(color='r'),mpatches.Patch(color='g'),mpatches.Patch(color='m')]
columns = [plt.plot([], [],'k', linestyle='--')[0],plt.plot([], [],'k', linestyle='-')[0]]
ax.legend(rows + columns, label_row + label_column, loc=4, prop={'size': 12})
ax.set_xlabel("physical error rate",fontname='Arial')
ax.set_ylabel("logical error rate per round",fontname='Arial' )
ax.grid()
plt.rcParams.update({'font.size': 15})
# plt.savefig("SCOSDvsOTF.pdf", format = "pdf", bbox_inches = "tight")
# plt.savefig("SCOSDvsOTF.pgf")

# %%
# Figure 3(a)
# Mean time plot(p=0.003), BP+BP+OTF vs BP+OSD-0
import matplotlib.pyplot as plt
import numpy as np

# X positions for each code
x = np.array([0, 1, 2, 3])

# Code labels for x-axis
code_labels = ['[[72,12,6]]', '[[108,8,10]]', '[[144,12,12]]', '[[288,12,18]]']

# Decoding times (in seconds)
bp_osd0 = np.array([0.000791494, 0.00304749, 0.00399665, 0.0185115])   # BP+OSD-0
bp_otf  = np.array([0.000213145, 0.000305058, 0.00046412, 0.0012316])   # BP+BP+OTF

# Colors for each code
colors = ['b', 'r', 'g', 'm']

# Create the plot
fig, ax = plt.subplots()

for i in range(len(x)):
    # Vertical line connecting the two methods
    ax.plot([x[i], x[i]], [bp_otf[i], bp_osd0[i]], color=colors[i], linewidth=2)

    # BP+OSD-0 marker (×)
    ax.plot(x[i], bp_osd0[i], 'x', color=colors[i], markersize=8, label='BP+OSD-0' if i == 0 else "")

    # BP+BP+OTF marker (o)
    ax.plot(x[i], bp_otf[i], 'o', color=colors[i], markerfacecolor='white', markersize=8, label='BP+BP+OTF' if i == 0 else "")

# Log scale for y-axis
ax.set_yscale('log')
ax.set_ylabel('Decoding time per round (s)')

# X-axis ticks and labels
ax.set_xticks(x)
ax.set_xticklabels(code_labels)
ax.set_ylim(1e-4, 1e-1)
# Legend
legend = ax.legend()
# Force all legend items (text and markers) to black
for text in legend.get_texts():
    text.set_color('black')
for handle in legend.legend_handles:
    handle.set_color('black')
    if hasattr(handle, 'set_markerfacecolor'):
        handle.set_markerfacecolor('white')  # preserve white fill for circle
        handle.set_markeredgecolor('black')
plt.rcParams.update({'font.size': 15})
plt.tight_layout()
plt.show()
# plt.savefig("timing_p_003.pgf")

# %%
# Figure 3(a)
# Mean time plot (p=0.004), BP+BP+OTF vs BP+OSD-0
import matplotlib.pyplot as plt
import numpy as np

# X positions for each code
x = np.array([0, 1, 2, 3])

# Code labels for x-axis
code_labels = ['[[72,12,6]]', '[[108,8,10]]', '[[144,12,12]]', '[[288,12,18]]']

# Decoding times (in seconds)
bp_osd0 = np.array([0.0030994, 0.00991958, 0.0146301, 0.0603348])   # BP+OSD-0
bp_otf  = np.array([0.000438171, 0.000494891, 0.000661266, 0.00182167])   # BP+BP+OTF

# Colors for each code
colors = ['b', 'r', 'g', 'm']

# Create the plot
fig, ax = plt.subplots()

for i in range(len(x)):
    # Vertical line connecting the two methods
    ax.plot([x[i], x[i]], [bp_otf[i], bp_osd0[i]], color=colors[i], linewidth=2)

    # BP+OSD-0 marker (×)
    ax.plot(x[i], bp_osd0[i], 'x', color=colors[i], markersize=8, label='BP+OSD-0' if i == 0 else "")

    # BP+BP+OTF marker (o)
    ax.plot(x[i], bp_otf[i], 'o', color=colors[i], markerfacecolor='white', markersize=8, label='BP+BP+OTF' if i == 0 else "")

# Log scale for y-axis
ax.set_yscale('log')
ax.set_ylabel('Decoding time per round (s)')

# X-axis ticks and labels
ax.set_xticks(x)
ax.set_xticklabels(code_labels)
ax.set_ylim(1e-4, 1e-1)
# Legend
legend = ax.legend()
# Force all legend items (text and markers) to black
for text in legend.get_texts():
    text.set_color('black')
for handle in legend.legend_handles:
    handle.set_color('black')
    if hasattr(handle, 'set_markerfacecolor'):
        handle.set_markerfacecolor('white')  # preserve white fill for circle
        handle.set_markeredgecolor('black')
plt.rcParams.update({'font.size': 15})
plt.tight_layout()
plt.show()
# plt.savefig("timing_p_004.pgf")

# %%
# Figure 6(b)
# BP+OSD-0 timing statistics at p=0.003 for the [[288,12,18]] code
import scipy.io

# --- Load data ---
# Load the .mat file (replace with your actual file path)
mat = scipy.io.loadmat('timings_otf_osd_18_p_0.003.mat')

times_osd = mat['times_osd'].squeeze()
times_otf = mat['times_otf'].squeeze()

# Normalize
normalized_osd = times_osd / 18

# Define log-spaced bins
bins = np.logspace(np.log10(1e-4), np.log10(10), 500)
bin_widths = np.diff(bins)

# Histogram without automatic normalization
counts, _ = np.histogram(normalized_osd, bins=bins)

# Manual PDF normalization
pdf = counts / 20000  # area = 1

# Bin centers
bin_centers = np.sqrt(bins[:-1] * bins[1:])

# Plot as bar-style histogram
plt.figure()
plt.bar(bin_centers, pdf, width=bin_widths, align='center', edgecolor='black')

plt.xscale('log')
plt.xlabel('Decoding time per round (s)')
plt.ylabel('Relative Frequency')
plt.grid(True, which='both', ls='--', linewidth=0.5)
plt.ylim(0, 0.08)
plt.xlim(1e-4, 10)
plt.rcParams.update({'font.size': 15})
plt.tight_layout()
plt.show()
# plt.savefig("OSDstatistics_p_003.pgf")

# %%
# Figure 6(a)
# BP+BP+OTF timing statistics at p=0.003 for the [[288,12,18]] code
import scipy.io

# --- Load data ---
# Load the .mat file (replace with your actual file path)
mat = scipy.io.loadmat('timings_otf_osd_18_p_0.003.mat')

times_osd = mat['times_osd'].squeeze()
times_otf = mat['times_otf'].squeeze()

# Normalize
normalized_osd = times_otf / 18

# Define log-spaced bins
bins = np.logspace(np.log10(1e-4), np.log10(10), 500)
bin_widths = np.diff(bins)

# Histogram without automatic normalization
counts, _ = np.histogram(normalized_osd, bins=bins)

# Manual PDF normalization
pdf = counts / 20000  # area = 1

# Bin centers
bin_centers = np.sqrt(bins[:-1] * bins[1:])

# Plot as bar-style histogram
plt.figure()
plt.bar(bin_centers, pdf, width=bin_widths, align='center', edgecolor='black')

plt.xscale('log')
plt.xlabel('Decoding time per round (s)')
plt.ylabel('Relative Frequency')
plt.grid(True, which='both', ls='--', linewidth=0.5)
plt.ylim(0, 0.08)
plt.xlim(1e-4, 10)
plt.rcParams.update({'font.size': 15})
plt.tight_layout()
plt.show()
# plt.savefig("OTFstatistics_p_003.pgf")

# %%
# Figure 6(d)
# BP+OSD-0 statistics at p=0.004 for the [[288,12,18]] code
import scipy.io

# --- Load data ---
# Load the .mat file (replace with your actual file path)
mat = scipy.io.loadmat('timings_otf_osd_18_p_0.004.mat')

times_osd = mat['times_osd'].squeeze()
times_otf = mat['times_otf'].squeeze()

# Normalize
normalized_osd = times_osd / 18

# Define log-spaced bins
bins = np.logspace(np.log10(1e-4), np.log10(10), 500)
bin_widths = np.diff(bins)

# Histogram without automatic normalization
counts, _ = np.histogram(normalized_osd, bins=bins)

# Manual PDF normalization
pdf = counts / 20000  # area = 1

# Bin centers
bin_centers = np.sqrt(bins[:-1] * bins[1:])

# Plot as bar-style histogram
plt.figure()
plt.bar(bin_centers, pdf, width=bin_widths, align='center', edgecolor='black')

plt.xscale('log')
plt.xlabel('Decoding time per round (s)')
plt.ylabel('Relative Frequency')
plt.grid(True, which='both', ls='--', linewidth=0.5)
plt.ylim(0, 0.035)
plt.xlim(1e-4, 10)
plt.rcParams.update({'font.size': 15})
plt.tight_layout()
plt.show()
# plt.savefig("OSDstatistics_p_004.pgf")

# %%
# Figure 6(c)
# BP+BP+OTF statistics at p=0.004 for the [[288,12,18]] code
import scipy.io

# --- Load data ---
# Load the .mat file (replace with your actual file path)
mat = scipy.io.loadmat('timings_otf_osd_18_p_0.004.mat')

times_osd = mat['times_osd'].squeeze()
times_otf = mat['times_otf'].squeeze()

# Normalize
normalized_osd = times_otf / 18

# Define log-spaced bins
bins = np.logspace(np.log10(1e-4), np.log10(10), 500)
bin_widths = np.diff(bins)

# Histogram without automatic normalization
counts, _ = np.histogram(normalized_osd, bins=bins)

# Manual PDF normalization
pdf = counts / 20000  # area = 1

# Bin centers
bin_centers = np.sqrt(bins[:-1] * bins[1:])

# Plot as bar-style histogram
plt.figure()
plt.bar(bin_centers, pdf, width=bin_widths, align='center', edgecolor='black')

plt.xscale('log')
plt.xlabel('Decoding time per round (s)')
plt.ylabel('Relative Frequency')
plt.grid(True, which='both', ls='--', linewidth=0.5)
plt.ylim(0, 0.035)
plt.xlim(1e-4, 10)
plt.rcParams.update({'font.size': 15})
plt.tight_layout()
plt.show()
# plt.savefig("OTFstatistics_p_004.pgf")
